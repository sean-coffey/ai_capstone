# %% [markdown]
# # Explore the aavail data

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# python module to create time series data frames for top 10 countries from source json
from ingestion import get_ts
from charts import *

data_dir = os.path.join(".", "data", "cs-train")
ts_all = get_ts(data_dir)

for key,item in ts_all.items():
    print(key,item.shape)
ts_all['all'].head()
# Out:
# ... loading ts data from files
# portugal (607, 7)
# united_kingdom (607, 7)
# hong_kong (426, 7)
# eire (607, 7)
# spain (607, 7)
# france (607, 7)
# singapore (456, 7)
# all (607, 7)
# norway (577, 7)
# germany (607, 7)
# netherlands (607, 7)
#          date  purchases  unique_invoices  unique_streams  total_views  \
# 0  2017-11-01          0                0               0            0
# 1  2017-11-02          0                0               0            0
# 2  2017-11-03          0                0               0            0
# 3  2017-11-04          0                0               0            0
# 4  2017-11-05          0                0               0            0
#
#   year_month  revenue
# 0    2017-11      0.0
# 1    2017-11      0.0
# 2    2017-11      0.0
# 3    2017-11      0.0
# 4    2017-11      0.0

# %%
ts_all['all'].describe()
# Out:
#          purchases  unique_invoices  unique_streams   total_views  \
# count   607.000000       607.000000      607.000000    607.000000
# mean   1273.464580        66.919275      658.074135   6651.255354
# std    1015.758467        47.871442      411.048951   4990.636140
# min       0.000000         0.000000        0.000000      0.000000
# 25%     634.500000        27.000000      435.500000   2681.500000
# 50%    1293.000000        70.000000      764.000000   7080.000000
# 75%    1752.500000        98.000000      934.000000   9368.000000
# max    7756.000000       219.000000     1596.000000  29374.000000
#
#              revenue
# count     607.000000
# mean     6131.698394
# std     10395.054288
# min    -44990.049000
# 25%      1805.780000
# 50%      4778.020000
# 75%      7640.235000
# max    170304.180000

# %%
create_normalised_line_plot(ts_all['all'])
plt.show()
# Out:
# ... creating plot
# ./plots/All-normalised_line_plot.png created.

# %%
ts_countries = dict(ts_all)
ts_countries.pop('all',None)
plot_attribute_by_country(ts_countries,'revenue')
plt.show
# Out:
# ./plots/revenue-by_country.png created.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plot_attribute_by_country(ts_countries,'purchases')
plt.show
# Out:
# ./plots/purchases-by_country.png created.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
normalised_by_country(ts_countries)
plt.show
# Out:
# ./plots/normalised_by_country.png created.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Notes on data
#
# 1. Data shows a significant year end peak in revenue for UK, Eire
# 2. Monthly Purchases and Revenue correlate for UK, Germany, Netherlands, Spain, France(?), but not for Singapore, Norway, Hong Kong, Portugal
# 3. UK Purchase volumes are 80x next largest country and 15x revenue
# 4. Hong Kong and Singapore are incomplete time-series, no data for 2019
